# %%
import requests 
from bs4 import BeautifulSoup
import re

# %%
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import os

chromedriver = "/Users/elaine/Dropbox/vcfriendfinder/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
import json
coData = []
with open('clean_salary_list.json', 'r') as f:
    colist = json.load(f)

# %%
from os import listdir
from os.path import isfile, join, isdir
dirs = [ './data/'+f for f in listdir('./data/') if isdir(join('./data/',f)) ]

# %%
ppl = x[x.keys()[0]].keys()

# %%
import time
chrome_options = Options()
chrome_options.add_extension('/Users/elaine/Dropbox/hook.crx')
#PROXY = "54.153.79.101:8888" # IP:PORT or HOST:PORT
#chrome_options.add_argument('--proxy-server=%s' % PROXY)

browser = webdriver.Chrome(chromedriver, chrome_options=chrome_options)

# %%
# for each linkedin profile
def dump_profiles(urls, pos, company):
    profiles = []
    for url in urls:
        browser.get(url)
        time.sleep(0.1)
        try:
            ent = browser.find_element_by_tag_name("body")
            profile = ent.find_element_by_id("background").get_attribute('innerHTML')
            profiles.append(profile)
        except:
            continue

        #for each title, save company, title, and array of profiles to disk
    #pdict = {'company': company, 'position': pos, 'profiles': profiles}
    parse_li(profiles, pos, company)

# %%
for c in colist[30:]:
    company = c.keys()[0]
    dump_url = 'data/' + company
    try:
        os.mkdir(dump_url)
    except:
        continue
    ppl = c[c.keys()[0]].keys()
    for goog in ppl:
        search = "https://www.linkedin.com/title/ " + goog + " at " + company
        #g = pygoogle(search)
        #g.pages = 1
        #try:
        #    li_url = g.get_urls()[0]
        #except:
        #    print goog
        #    print ppl.index(goog)
        #time.sleep(1)

        r = requests.get(search)
        profiles = BeautifulSoup(r.content).findAll('li',{'class': 'item-container'})
        urls = []
        for p in profiles[:4]:
            href = p.find('a')['href']
            urls.append(href)
        goog = goog.replace("/","-")
        dump_profiles(urls, goog, company)
        #li_urls.append({'position':goog, 'company':company, 'profiles': urls})
        #parse_li(urls, goog, company)

# %%
boxes =['background-summary-container','background-experience-container',
        'background-languages-container', 'background-skills-container',
       'background-education-container','background-honors-container']

def parse_li(profiles, position, company):
    cleanprofiles = []
    for p in profiles:
        content = ""
        for b in boxes:
            try:
                divs = BeautifulSoup(p).find('div', {'id': b})
                for script in divs(["script", "style"]):
                    script.extract()    # rip it out   
                for d in divs.findAll('div'):
                    content += " ".join(d.strings) + " "
            except:
                continue
        cleanprofiles.append(content)
    x = {'company': company, 'profiles': cleanprofiles, 
         'position': position.replace("/","-")}
    with open('data/'+company+'/'+x['position']+'.json','w') as f:
        json.dump(x, f)

# %%
len(ppl)
# Out:
# 371

# %%
colist.index(c)
# Out:
# 29

# %%
c
# Out:
# {u'Alcatel-Lucent Holding': {u'4G/LTE Customer Support (Development) Engineer': {u'count': 1,
#    u'max': u' $99k',
#    u'mean': u'n/a',
#    u'min': u' $91k'},
#   u'Account Executive (Systems Analyst)': {u'count': 1,
#    u'max': u' $137k',
#    u'mean': u'n/a',
#    u'min': u' $126k'},
#   u'Advanced Applications Tendering Manager': {u'count': 2,
#    u'max': u' $71k',
#    u'mean': u'$66,753',
#    u'min': u' $63k'},
#   u'Advanced Coherent Optical Communication Researcher': {u'count': 1,
#    u'max': u' $93k',
#    u'mean': u'n/a',
#    u'min': u' $86k'},
#   u'Advanced Optical Network Architect': {u'count': 1,
#    u'max': u' $117k',
#    u'mean': u'n/a',
#    u'min': u' $107k'},
#   u'Algorithms Research Member of Technical': {u'count': 1,
#    u'max': u' $134k',
#    u'mean': u'n/a',
#    u'min': u' $122k'},
#   u'Applications Developer': {u'count': 1,
#    u'max': u' $87k',
#    u'mean': u'n/a',
#    u'min': u' $80k'},
#   u'Automation Test Engineer': {u'count': 1,
#    u'max': u' $91k',
#    u'mean': u'n/a',
#    u'min': u' $84k'},
#   u'Bell Labs - Thermal Management Researcher, Postdoctoral': {u'count': 1,
#    u'max': u' $85k',
#    u'mean': u'n/a',
#    u'min': u' $78k'},
#   u'Bell Labs - Thermal Management Researcher, Postdoctoral - Hourly': {u'count': 1,
#    u'max': u' $42',
#    u'mean': u'n/a',
#    u'min': u' $39'},
#   u'Business Development Manager': {u'count': 1,
#    u'max': u' $99k',
#    u'mean': u'n/a',
#    u'min': u' $91k'},
#   u'Business Development Manager Mmi Smo': {u'count': 1,
#    u'max': u' $157k',
#    u'mean': u'n/a',
#    u'min': u' $146k'},
#   u'Business Development and Product Marketing Manager': {u'count': 1,
#    u'max': u' $140k',
#    u'mean': u'n/a',
#    u'min': u' $131k'},
#   u'Cli Snmp Agent Development Engineer': {u'count': 6,
#    u'max': u' $145k',
#    u'mean': u'$126,744',
#    u'min': u' $113k'},
#   u'Communications Networks Researcher': {u'count': 2,
#    u'max': u' $137k',
#    u'mean': u'$128,059',
#    u'min': u' $119k'},
#   u'Complex Solution Integrator': {u'count': 1,
#    u'max': u' $98k',
#    u'mean': u'n/a',
#    u'min': u' $90k'},
#   u'Computer Software Engineer/Technical Marketing Eng': {u'count': 1,
#    u'max': u' $86k',
#    u'mean': u'n/a',
#    u'min': u' $81k'},
#   u'Consulting Engineer': {u'count': 1,
#    u'max': u' $111k',
#    u'mean': u'n/a',
#    u'min': u' $101k'},
#   u'Consulting Product Manager': {u'count': 2,
#    u'max': u' $103k',
#    u'mean': u'$98,550',
#    u'min': u' $94k'},
#   u'Core Integration Engineer': {u'count': 1,
#    u'max': u' $82k',
#    u'mean': u'n/a',
#    u'min': u' $75k'},
#   u'Ctac Engineer': {u'count': 1,
#    u'max': u' $125k',
#    u'mean': u'n/a',
#    u'min': u' $114k'},
#   u'Customer Applications Engineer Specialist': {u'count': 4,
#    u'max': u' $114k',
#    u'mean': u'$99,040',
#    u'min': u' $86k'},
#   u'Customer Applications Engineering Senior': {u'count': 1,
#    u'max': u' $117k',
#    u'mean': u'n/a',
#    u'min': u' $108k'},
#   u'Customer Applications Engineering Specialist': {u'count': 2,
#    u'max': u' $88k',
#    u'mean': u'$83,781',
#    u'min': u' $79k'},
#   u'Customer Project Management': {u'count': 1,
#    u'max': u' $125k',
#    u'mean': u'n/a',
#    u'min': u' $114k'},
#   u'Customer Project Manager': {u'count': 2,
#    u'max': u' $127k',
#    u'mean': u'$122,560',
#    u'min': u' $118k'},
#   u'Customer Solution Manager': {u'count': 1,
#    u'max': u' $115k',
#    u'mean': u'n/a',
#    u'min': u' $107k'},
#   u'Customer Support Engineer': {u'count': 1,
#    u'max': u' $102k',
#    u'mean': u'n/a',
#    u'min': u' $94k'},
#   u'Customer Technical Advocate': {u'count': 2,
#    u'max': u' $109k',
#    u'mean': u'$102,692',
#    u'min': u' $97k'},
#   u'Customer Technical Support': {u'count': 1,
#    u'max': u' $113k',
#    u'mean': u'n/a',
#    u'min': u' $105k'},
#   u'Customized Focused Testing Engineer': {u'count': 1,
#    u'max': u' $86k',
#    u'mean': u'n/a',
#    u'min': u' $80k'},
#   u'Director': {u'count': 1,
#    u'max': u' $125k',
#    u'mean': u'n/a',
#    u'min': u' $116k'},
#   u'Director Mobile Ngn Global Product Support': {u'count': 1,
#    u'max': u' $146k',
#    u'mean': u'n/a',
#    u'min': u' $135k'},
#   u'Director Product and Solution Market Engineering': {u'count': 1,
#    u'max': u' $167k',
#    u'mean': u'n/a',
#    u'min': u' $155k'},
#   u'Director, Mobile Ngn Technical Engineering Center': {u'count': 1,
#    u'max': u' $151k',
#    u'mean': u'n/a',
#    u'min': u' $141k'},
#   u'Director, Solution Marketing': {u'count': 1,
#    u'max': u' $169k',
#    u'mean': u'n/a',
#    u'min': u' $155k'},
#   u'Engagement Assurance Manager': {u'count': 1,
#    u'max': u' $152k',
#    u'mean': u'n/a',
#    u'min': u' $140k'},
#   u'Field Engineer UMTS/Lte Demo Team': {u'count': 1,
#    u'max': u' $103k',
#    u'mean': u'n/a',
#    u'min': u' $95k'},
#   u'Financial Planning Analyst': {u'count': 1,
#    u'max': u' $97k',
#    u'mean': u'n/a',
#    u'min': u' $88k'},
#   u'Genesys Resident Engineer': {u'count': 1,
#    u'max': u' $119k',
#    u'mean': u'n/a',
#    u'min': u' $109k'},
#   u'Global Service Manager (Gsm)': {u'count': 2,
#    u'max': u' $153k',
#    u'mean': u'$146,240',
#    u'min': u' $139k'},
#   u'HW/Software Diagnostic Engineer': {u'count': 1,
#    u'max': u' $140k',
#    u'mean': u'n/a',
#    u'min': u' $129k'},
#   u'Hardware Engineering Technician': {u'count': 1,
#    u'max': u' $99k',
#    u'mean': u'n/a',
#    u'min': u' $91k'},
#   u'IP Design Engineer': {u'count': 1,
#    u'max': u' $115k',
#    u'mean': u'n/a',
#    u'min': u' $106k'},
#   u'IP Network Architect': {u'count': 2,
#    u'max': u' $165k',
#    u'mean': u'$154,122',
#    u'min': u' $143k'},
#   u'Ims Solutions Engineer': {u'count': 2,
#    u'max': u' $106k',
#    u'mean': u'$99,227',
#    u'min': u' $93k'},
#   u'In Building Systems Solution Engineer': {u'count': 1,
#    u'max': u' $115k',
#    u'mean': u'n/a',
#    u'min': u' $106k'},
#   u'In-building Das Systems Solution Engineer': {u'count': 6,
#    u'max': u' $105k',
#    u'mean': u'$93,052',
#    u'min': u' $83k'},
#   u'Insource Applications Support - Member of Technical Staff': {u'count': 1,
#    u'max': u' $90k',
#    u'mean': u'n/a',
#    u'min': u' $83k'},
#   u'Integration Consultant': {u'count': 1,
#    u'max': u' $97k',
#    u'mean': u'n/a',
#    u'min': u' $90k'},
#   u'Integration Professional': {u'count': 6,
#    u'max': u' $122k',
#    u'mean': u'$110,140',
#    u'min': u' $91k'},
#   u'Integration Professional (Computer Engineering)': {u'count': 1,
#    u'max': u' $92k',
#    u'mean': u'n/a',
#    u'min': u' $84k'},
#   u'Ipbh & Mwbh Senior Operation Engineer': {u'count': 1,
#    u'max': u' $98k',
#    u'mean': u'n/a',
#    u'min': u' $91k'},
#   u'Ipd Resident Engineer': {u'count': 1,
#    u'max': u' $87k',
#    u'mean': u'n/a',
#    u'min': u' $79k'},
#   u'Ips Business Development Manager': {u'count': 2,
#    u'max': u' $114k',
#    u'mean': u'$107,666',
#    u'min': u' $102k'},
#   u'L2 Support Engineer': {u'count': 1,
#    u'max': u' $74k',
#    u'mean': u'n/a',
#    u'min': u' $68k'},
#   u'LTE Development Engineer': {u'count': 3,
#    u'max': u' $130k',
#    u'mean': u'$122,653',
#    u'min': u' $116k'},
#   u'LTE Feature Tester': {u'count': 1,
#    u'max': u' $81k',
#    u'mean': u'n/a',
#    u'min': u' $74k'},
#   u'LTE RAN Engineer': {u'count': 2,
#    u'max': u' $98k',
#    u'mean': u'$89,748',
#    u'min': u' $82k'},
#   u'LTE RF Optimization Engineer': {u'count': 1,
#    u'max': u' $113k',
#    u'mean': u'n/a',
#    u'min': u' $103k'},
#   u'Lead Engineer': {u'count': 3,
#    u'max': u' $147k',
#    u'mean': u'$136,117',
#    u'min': u' $126k'},
#   u'Lead Software Engineer': {u'count': 4,
#    u'max': u' $148k',
#    u'mean': u'$129,370',
#    u'min': u' $116k'},
#   u'Lead Software Test Engineer': {u'count': 1,
#    u'max': u' $94k',
#    u'mean': u'n/a',
#    u'min': u' $86k'},
#   u'Lead Solution Architect - Radio Frequency Engineer': {u'count': 1,
#    u'max': u' $99k',
#    u'mean': u'n/a',
#    u'min': u' $90k'},
#   u'Lead Test and Validation Engineer': {u'count': 1,
#    u'max': u' $87k',
#    u'mean': u'n/a',
#    u'min': u' $80k'},
#   u'Lgp Systems Engineer': {u'count': 1,
#    u'max': u' $117k',
#    u'mean': u'n/a',
#    u'min': u' $107k'},
#   u'Lte Software Development Engineer': {u'count': 4,
#    u'max': u' $115k',
#    u'mean': u'$95,440',
#    u'min': u' $78k'},
#   u'Lte Test Engineer': {u'count': 3,
#    u'max': u' $138k',
#    u'mean': u'$104,634',
#    u'min': u' $87k'},
#   u'Lte Tis - Technical Project Manager': {u'count': 1,
#    u'max': u' $118k',
#    u'mean': u'n/a',
#    u'min': u' $110k'},
#   u'Lte Voice and Data Quality Engineer': {u'count': 2,
#    u'max': u' $112k',
#    u'mean': u'$105,829',
#    u'min': u' $100k'},
#   u'Manager - Software Development Engineering': {u'count': 1,
#    u'max': u' $148k',
#    u'mean': u'n/a',
#    u'min': u' $138k'},
#   u'Manager Customer Applications Engineering': {u'count': 1,
#    u'max': u' $117k',
#    u'mean': u'n/a',
#    u'min': u' $110k'},
#   u'Manager Hris Data Center': {u'count': 1,
#    u'max': u' $112k',
#    u'mean': u'n/a',
#    u'min': u' $104k'},
#   u'Manager Systems Development/Integration Engineer': {u'count': 1,
#    u'max': u' $121k',
#    u'mean': u'n/a',
#    u'min': u' $111k'},
#   u'Manager, Lead Global Human Resources Reporting and Compliance': {u'count': 1,
#    u'max': u' $115k',
#    u'mean': u'n/a',
#    u'min': u' $106k'},
#   u'Manager, Software Development & Engineering': {u'count': 3,
#    u'max': u' $157k',
#    u'mean': u'$140,635',
#    u'min': u' $123k'},
#   u'Manager, Software Development Engineer': {u'count': 1,
#    u'max': u' $150k',
#    u'mean': u'n/a',
#    u'min': u' $137k'},
#   u'Member Technical Staff': {u'count': 1,
#    u'max': u' $122k',
#    u'mean': u'n/a',
#    u'min': u' $115k'},
#   u'Member Technical Staff - Research': {u'count': 1,
#    u'max': u' $129k',
#    u'mean': u'n/a',
#    u'min': u' $120k'},
#   u'Member of Technical Staff': {u'count': 21,
#    u'max': u' $138k',
#    u'mean': u'$115,129',
#    u'min': u' $82k'},
#   u'Member of Technical Staff (Member of Technical Staff)': {u'count': 1,
#    u'max': u' $154k',
#    u'mean': u'n/a',
#    u'min': u' $142k'},
#   u'Member of Technical Staff (Network Engineer)': {u'count': 2,
#    u'max': u' $128k',
#    u'mean': u'$120,284',
#    u'min': u' $112k'},
#   u'Member of Technical Staff (Network Processor)': {u'count': 1,
#    u'max': u' $129k',
#    u'mean': u'n/a',
#    u'min': u' $119k'},
#   u'Member of Technical Staff (Systems Administrator)': {u'count': 1,
#    u'max': u' $105k',
#    u'mean': u'n/a',
#    u'min': u' $99k'},
#   u'Member of Technical Staff (Systems Test Engineer)': {u'count': 2,
#    u'max': u' $103k',
#    u'mean': u'$90,587',
#    u'min': u' $78k'},
#   u'Member of Technical Staff - Access Network Solution': {u'count': 2,
#    u'max': u' $128k',
#    u'mean': u'$122,050',
#    u'min': u' $116k'},
#   u'Member of Technical Staff - Communications Network': {u'count': 1,
#    u'max': u' $127k',
#    u'mean': u'n/a',
#    u'min': u' $119k'},
#   u'Member of Technical Staff - Network Architect': {u'count': 1,
#    u'max': u' $124k',
#    u'mean': u'n/a',
#    u'min': u' $114k'},
#   u'Member of Technical Staff - Networking Research': {u'count': 1,
#    u'max': u' $132k',
#    u'mean': u'n/a',
#    u'min': u' $123k'},
#   u'Member of Technical Staff - Statistical Researcher': {u'count': 1,
#    u'max': u' $124k',
#    u'mean': u'n/a',
#    u'min': u' $115k'},
#   u'Member of Technical Staff - Windows Applications Support Specialist': {u'count': 2,
#    u'max': u' $103k',
#    u'mean': u'$98,043',
#    u'min': u' $93k'},
#   u'Member of Technical Staff Software Engineer': {u'count': 1,
#    u'max': u' $115k',
#    u'mean': u'n/a',
#    u'min': u' $106k'},
#   u'Member of Technical Staff, Business Development Applications Americas': {u'count': 1,
#    u'max': u' $96k',
#    u'mean': u'n/a',
#    u'min': u' $88k'},
#   u'Mrg Systems Test Engineer': {u'count': 1,
#    u'max': u' $109k',
#    u'mean': u'n/a',
#    u'min': u' $100k'},
#   u'Ms Cala Senior Manager': {u'count': 1,
#    u'max': u' $128k',
#    u'mean': u'n/a',
#    u'min': u' $118k'},
#   u'Network Architect Senior': {u'count': 2,
#    u'max': u' $127k',
#    u'mean': u'$118,947',
#    u'min': u' $111k'},
#   u'Network Design Engineer': {u'count': 4,
#    u'max': u' $86k',
#    u'mean': u'$83,183',
#    u'min': u' $81k'},
#   u'Network Design Radio Competence Center Manager': {u'count': 1,
#    u'max': u' $107k',
#    u'mean': u'n/a',
#    u'min': u' $99k'},
#   u'Network Design Specialist': {u'count': 1,
#    u'max': u' $106k',
#    u'mean': u'n/a',
#    u'min': u' $98k'},
#   u'Network Engineer': {u'count': 3,
#    u'max': u' $84k',
#    u'mean': u'$76,589',
#    u'min': u' $73k'},
#   u'Network Integration Engineer': {u'count': 1,
#    u'max': u' $130k',
#    u'mean': u'n/a',
#    u'min': u' $120k'},
#   u'Network Researcher': {u'count': 1,
#    u'max': u' $133k',
#    u'mean': u'n/a',
#    u'min': u' $123k'},
#   u'Network Support Engineer': {u'count': 2,
#    u'max': u' $89k',
#    u'mean': u'$84,258',
#    u'min': u' $79k'},
#   u'New Product Certification Support Specialist': {u'count': 1,
#    u'max': u' $110k',
#    u'mean': u'n/a',
#    u'min': u' $102k'},
#   u'New Product Integration Engineer': {u'count': 1,
#    u'max': u' $117k',
#    u'mean': u'n/a',
#    u'min': u' $110k'},
#   u'New Product Introduction Engineer': {u'count': 1,
#    u'max': u' $118k',
#    u'mean': u'n/a',
#    u'min': u' $110k'},
#   u'New Product Specialist': {u'count': 1,
#    u'max': u' $93k',
#    u'mean': u'n/a',
#    u'min': u' $87k'},
#   u'New Product Specialist - Mts-1': {u'count': 1,
#    u'max': u' $90k',
#    u'mean': u'n/a',
#    u'min': u' $84k'},
#   u'Optical Technical Support Engineer': {u'count': 1,
#    u'max': u' $110k',
#    u'mean': u'n/a',
#    u'min': u' $102k'},
#   u'Post Doctoral Researcher (Member of Technical Staf': {u'count': 2,
#    u'max': u' $85k',
#    u'mean': u'$81,818',
#    u'min': u' $78k'},
#   u'Postdoctoral Member of Technical Staff': {u'count': 2,
#    u'max': u' $85k',
#    u'mean': u'$79,955',
#    u'min': u' $75k'},
#   u'Practice Manager (Software Engineering)': {u'count': 1,
#    u'max': u' $150k',
#    u'mean': u'n/a',
#    u'min': u' $140k'},
#   u'Principal Consultant Professional Services': {u'count': 1,
#    u'max': u' $107k',
#    u'mean': u'n/a',
#    u'min': u' $98k'},
#   u'Principal Engineer': {u'count': 1,
#    u'max': u' $154k',
#    u'mean': u'n/a',
#    u'min': u' $144k'},
#   u'Principal Systems Engineer': {u'count': 1,
#    u'max': u' $154k',
#    u'mean': u'n/a',
#    u'min': u' $142k'},
#   u'Product Manager': {u'count': 4,
#    u'max': u' $147k',
#    u'mean': u'$134,527',
#    u'min': u' $126k'},
#   u'Product Planning Manager': {u'count': 2,
#    u'max': u' $93k',
#    u'mean': u'$89,307',
#    u'min': u' $86k'},
#   u'Product Systems Test Engineer': {u'count': 1,
#    u'max': u' $121k',
#    u'mean': u'n/a',
#    u'min': u' $111k'},
#   u'Program Manager': {u'count': 1,
#    u'max': u' $121k',
#    u'mean': u'n/a',
#    u'min': u' $111k'},
#   u'Program/Project Manager': {u'count': 1,
#    u'max': u' $83k',
#    u'mean': u'n/a',
#    u'min': u' $77k'},
#   u'Project Manager': {u'count': 1,
#    u'max': u' $80k',
#    u'mean': u'n/a',
#    u'min': u' $73k'},
#   u'Project Manager - Contractor': {u'count': 1,
#    u'max': u' $82k',
#    u'mean': u'n/a',
#    u'min': u' $76k'},
#   u'Project Manager Customer Specialist': {u'count': 1,
#    u'max': u' $101k',
#    u'mean': u'n/a',
#    u'min': u' $92k'},
#   u'Quality Assurance Engineering Specialist': {u'count': 1,
#    u'max': u' $98k',
#    u'mean': u'n/a',
#    u'min': u' $90k'},
#   u'RF Engineer': {u'count': 3,
#    u'max': u' $108k',
#    u'mean': u'$98,435',
#    u'min': u' $92k'},
#   u'RF Engineer - Member of Technical Staff': {u'count': 2,
#    u'max': u' $121k',
#    u'mean': u'$110,006',
#    u'min': u' $99k'},
#   u'RF Optimization Engineer': {u'count': 7,
#    u'max': u' $105k',
#    u'mean': u'$96,647',
#    u'min': u' $92k'},
#   u'RF Services Delivery Engineer': {u'count': 3,
#    u'max': u' $82k',
#    u'mean': u'$80,334',
#    u'min': u' $79k'},
#   u'Radio Frequency Engineer': {u'count': 1,
#    u'max': u' $114k',
#    u'mean': u'n/a',
#    u'min': u' $106k'},
#   u'Radio Frequency Engineer (Member of Technical Staf': {u'count': 1,
#    u'max': u' $106k',
#    u'mean': u'n/a',
#    u'min': u' $97k'},
#   u'Radio Performance Engineer': {u'count': 2,
#    u'max': u' $123k',
#    u'mean': u'$117,743',
#    u'min': u' $112k'},
#   u'Reliability Software Developer': {u'count': 1,
#    u'max': u' $94k',
#    u'mean': u'n/a',
#    u'min': u' $86k'},
#   u'Research Engineer': {u'count': 2,
#    u'max': u' $135k',
#    u'mean': u'$125,025',
#    u'min': u' $115k'},
#   u'Research Engineering Professional': {u'count': 1,
#    u'max': u' $126k',
#    u'mean': u'n/a',
#    u'min': u' $118k'},
#   u'Research Scientist': {u'count': 1,
#    u'max': u' $127k',
#    u'mean': u'n/a',
#    u'min': u' $116k'},
#   u'Researcher': {u'count': 1,
#    u'max': u' $126k',
#    u'mean': u'n/a',
#    u'min': u' $116k'},
#   u'Resident Engineer': {u'count': 1,
#    u'max': u' $118k',
#    u'mean': u'n/a',
#    u'min': u' $109k'},
#   u'Senior Account Director': {u'count': 1,
#    u'max': u' $129k',
#    u'mean': u'n/a',
#    u'min': u' $119k'},
#   u'Senior Business Systems Programmer/Analyst': {u'count': 2,
#    u'max': u' $111k',
#    u'mean': u'$106,558',
#    u'min': u' $102k'},
#   u'Senior Design Engineer': {u'count': 1,
#    u'max': u' $167k',
#    u'mean': u'n/a',
#    u'min': u' $155k'},
#   u'Senior Director, Solutions Management': {u'count': 1,
#    u'max': u' $227k',
#    u'mean': u'n/a',
#    u'min': u' $212k'},
#   u'Senior Engineer': {u'count': 1,
#    u'max': u' $116k',
#    u'mean': u'n/a',
#    u'min': u' $107k'},
#   u'Senior Financial Analyst': {u'count': 2,
#    u'max': u' $107k',
#    u'mean': u'$100,698',
#    u'min': u' $95k'},
#   u'Senior Global Financial Planning Analyst': {u'count': 1,
#    u'max': u' $92k',
#    u'mean': u'n/a',
#    u'min': u' $84k'},
#   u'Senior Integration Consultant': {u'count': 1,
#    u'max': u' $111k',
#    u'mean': u'n/a',
#    u'min': u' $101k'},
#   u'Senior LTE (Long Term Evolution) Test Engineer': {u'count': 1,
#    u'max': u' $125k',
#    u'mean': u'n/a',
#    u'min': u' $115k'},
#   u'Senior LTE Development Engineer': {u'count': 3,
#    u'max': u' $150k',
#    u'mean': u'$144,048',
#    u'min': u' $138k'},
#   u'Senior Lte Test Engineer': {u'count': 3,
#    u'max': u' $132k',
#    u'mean': u'$129,490',
#    u'min': u' $127k'},
#   u'Senior Manager': {u'count': 3,
#    u'max': u' $141k',
#    u'mean': u'$131,777',
#    u'min': u' $116k'},
#   u'Senior Network Architect (Resident Engineer)': {u'count': 1,
#    u'max': u' $98k',
#    u'mean': u'n/a',
#    u'min': u' $91k'},
#   u'Senior Principal Engineer - Architecture & Design': {u'count': 1,
#    u'max': u' $124k',
#    u'mean': u'n/a',
#    u'min': u' $116k'},
#   u'Senior Product Manager': {u'count': 2,
#    u'max': u' $187k',
#    u'mean': u'$150,736',
#    u'min': u' $115k'},
#   u'Senior Product Marketing Manager': {u'count': 1,
#    u'max': u' $126k',
#    u'mean': u'n/a',
#    u'min': u' $117k'},
#   u'Senior Product and Solutions Manager': {u'count': 1,
#    u'max': u' $120k',
#    u'mean': u'n/a',
#    u'min': u' $112k'},
#   u'Senior Professional Services Engineer': {u'count': 1,
#    u'max': u' $115k',
#    u'mean': u'n/a',
#    u'min': u' $108k'},
#   u'Senior Professional Services Engineer/Smb Project': {u'count': 1,
#    u'max': u' $121k',
#    u'mean': u'n/a',
#    u'min': u' $112k'},
#   u'Senior Project Manager': {u'count': 1,
#    u'max': u' $104k',
#    u'mean': u'n/a',
#    u'min': u' $96k'},
#   u'Senior Quality Assurance Engineer': {u'count': 1,
#    u'max': u' $117k',
#    u'mean': u'n/a',
#    u'min': u' $108k'},
#   u'Senior Software Design Engineer': {u'count': 1,
#    u'max': u' $146k',
#    u'mean': u'n/a',
#    u'min': u' $136k'},
#   u'Senior Software Development Engineer': {u'count': 12,
#    u'max': u' $166k',
#    u'mean': u'$119,212',
#    u'min': u' $96k'},
#   u'Senior Software Engineer': {u'count': 11,
#    u'max': u' $182k',
#    u'mean': u'$138,857',
#    u'min': u' $109k'},
#   u'Senior Software Engineer - Quality Assurance': {u'count': 2,
#    u'max': u' $149k',
#    u'mean': u'$140,748',
#    u'min': u' $133k'},
#   u'Senior Software QA Engineer': {u'count': 15,
#    u'max': u' $163k',
#    u'mean': u'$133,960',
#    u'min': u' $107k'},
#   u'Senior Software Quality Assurance Engineer': {u'count': 2,
#    u'max': u' $137k',
#    u'mean': u'$125,867',
#    u'min': u' $115k'},
#   u'Senior Solutions Architect': {u'count': 2,
#    u'max': u' $129k',
#    u'mean': u'$122,728',
#    u'min': u' $116k'},
#   u'Senior Sourcing Engineer': {u'count': 1,
#    u'max': u' $98k',
#    u'mean': u'n/a',
#    u'min': u' $91k'},
#   u'Senior Sourcing Manager': {u'count': 1,
#    u'max': u' $98k',
#    u'mean': u'n/a',
#    u'min': u' $89k'},
#   u'Senior Staff Engineer': {u'count': 1,
#    u'max': u' $165k',
#    u'mean': u'n/a',
#    u'min': u' $153k'},
#   u'Senior Systems Development/Integration Engineer': {u'count': 1,
#    u'max': u' $130k',
#    u'mean': u'n/a',
#    u'min': u' $119k'},
#   u'Senior Systems Engineer': {u'count': 2,
#    u'max': u' $114k',
#    u'mean': u'$99,624',
#    u'min': u' $85k'},
#   u'Senior Technical Instructor and Course Developer': {u'count': 3,
#    u'max': u' $122k',
#    u'mean': u'$118,749',
#    u'min': u' $117k'},
#   u'Senior Technical Support Engineer': {u'count': 2,
#    u'max': u' $122k',
#    u'mean': u'$108,610',
#    u'min': u' $96k'},
#   u'Senior Test Engineer/LTE Test Engineer': {u'count': 1,
#    u'max': u' $146k',
#    u'mean': u'n/a',
#    u'min': u' $134k'},
#   u'Software Customer Applications Professional': {u'count': 1,
#    u'max': u' $104k',
#    u'mean': u'n/a',
#    u'min': u' $96k'},
#   u'Software Design Engineer': {u'count': 1,
#    u'max': u' $119k',
#    u'mean': u'n/a',
#    u'min': u' $109k'},
#   u'Software Developer': {u'count': 5,
#    u'max': u' $138k',
#    u'mean': u'$105,958',
#    u'min': u' $73k'},
#   u'Software Developer Engineer Specialist': {u'count': 1,
#    u'max': u' $114k',
#    u'mean': u'n/a',
#    u'min': u' $106k'},
#   u'Software Developer, 9900 Wireless Network Guardian': {u'count': 3,
#    u'max': u' $124k',
#    u'mean': u'$122,293',
#    u'min': u' $121k'},
#   u'Software Development Engineer': {u'count': 54,
#    u'max': u' $148k',
#    u'mean': u'$111,865',
#    u'min': u' $81k'},
#   u'Software Development Engineer (Systems Test Team Le': {u'count': 2,
#    u'max': u' $130k',
#    u'mean': u'$122,907',
#    u'min': u' $116k'},
#   u'Software Development Engineer (Technical Lead)': {u'count': 1,
#    u'max': u' $174k',
#    u'mean': u'n/a',
#    u'min': u' $163k'},
#   u'Software Development Engineer III': {u'count': 1,
#    u'max': u' $144k',
#    u'mean': u'n/a',
#    u'min': u' $135k'},
#   u'Software Development Engineer Specialist': {u'count': 14,
#    u'max': u' $149k',
#    u'mean': u'$96,373',
#    u'min': u' $80k'},
#   u'Software Development Engineering Staff': {u'count': 1,
#    u'max': u' $156k',
#    u'mean': u'n/a',
#    u'min': u' $144k'},
#   u'Software Engineer': {u'count': 6,
#    u'max': u' $126k',
#    u'mean': u'$111,270',
#    u'min': u' $94k'},
#   u'Software Engineer II': {u'count': 1,
#    u'max': u' $122k',
#    u'mean': u'n/a',
#    u'min': u' $112k'},
#   u'Software Engineer Staff': {u'count': 1,
#    u'max': u' $126k',
#    u'mean': u'n/a',
#    u'min': u' $118k'},
#   u'Software Engineer/Developer': {u'count': 1,
#    u'max': u' $124k',
#    u'mean': u'n/a',
#    u'min': u' $113k'},
#   u'Software Integration Consultant': {u'count': 1,
#    u'max': u' $117k',
#    u'mean': u'n/a',
#    u'min': u' $109k'},
#   u'Software Integration/Automation Tester': {u'count': 1,
#    u'max': u' $86k',
#    u'mean': u'n/a',
#    u'min': u' $79k'},
#   u'Software Product Development': {u'count': 1,
#    u'max': u' $111k',
#    u'mean': u'n/a',
#    u'min': u' $102k'},
#   u'Software QA Engineer': {u'count': 21,
#    u'max': u' $130k',
#    u'mean': u'$113,653',
#    u'min': u' $98k'},
#   u'Software Quality Assurance Engineer': {u'count': 81,
#    u'max': u' $144k',
#    u'mean': u'$111,550',
#    u'min': u' $86k'},
#   u'Software Quality Assurance Engineer III': {u'count': 2,
#    u'max': u' $143k',
#    u'mean': u'$134,038',
#    u'min': u' $125k'},
#   u'Software Quality Assurance Engineer Specialist': {u'count': 4,
#    u'max': u' $141k',
#    u'mean': u'$103,801',
#    u'min': u' $85k'},
#   u'Software Solution Architect': {u'count': 1,
#    u'max': u' $101k',
#    u'mean': u'n/a',
#    u'min': u' $92k'},
#   u'Software Test Engineer': {u'count': 12,
#    u'max': u' $149k',
#    u'mean': u'$126,919',
#    u'min': u' $104k'},
#   u'Software Test Specialist': {u'count': 5,
#    u'max': u' $141k',
#    u'mean': u'$122,657',
#    u'min': u' $105k'},
#   u'Solution Architect/Radio Frequency Engineer': {u'count': 1,
#    u'max': u' $102k',
#    u'mean': u'n/a',
#    u'min': u' $95k'},
#   u'Solutions Architect': {u'count': 3,
#    u'max': u' $142k',
#    u'mean': u'$113,449',
#    u'min': u' $86k'},
#   u'Solutions Engineer': {u'count': 1,
#    u'max': u' $128k',
#    u'mean': u'n/a',
#    u'min': u' $118k'},
#   u'Spss Senior Manager': {u'count': 1,
#    u'max': u' $136k',
#    u'mean': u'n/a',
#    u'min': u' $126k'},
#   u'Staff Engineer': {u'count': 1,
#    u'max': u' $125k',
#    u'mean': u'n/a',
#    u'min': u' $117k'},
#   u'Staff Software Engineer': {u'count': 1,
#    u'max': u' $135k',
#    u'mean': u'n/a',
#    u'min': u' $124k'},
#   u'Staff Software Engineer - Team Lead': {u'count': 1,
#    u'max': u' $127k',
#    u'mean': u'n/a',
#    u'min': u' $117k'},
#   u'Standards Engineer': {u'count': 1,
#    u'max': u' $126k',
#    u'mean': u'n/a',
#    u'min': u' $117k'},
#   u'Standards Engineer - Lte Security': {u'count': 1,
#    u'max': u' $113k',
#    u'mean': u'n/a',
#    u'min': u' $104k'},
#   u'Statistics & Learning Researcher': {u'count': 1,
#    u'max': u' $142k',
#    u'mean': u'n/a',
#    u'min': u' $131k'},
#   u'Sustainable Power Engineer for Telecommunications': {u'count': 1,
#    u'max': u' $81k',
#    u'mean': u'n/a',
#    u'min': u' $75k'},
#   u'Systems Analyst': {u'count': 2,
#    u'max': u' $102k',
#    u'mean': u'$97,106',
#    u'min': u' $93k'},
#   u'Systems Development Engineer': {u'count': 2,
#    u'max': u' $141k',
#    u'mean': u'$111,893',
#    u'min': u' $82k'},
#   u'Systems Engineer': {u'count': 1,
#    u'max': u' $134k',
#    u'mean': u'n/a',
#    u'min': u' $124k'},
#   u'Systems Engineer - Development': {u'count': 1,
#    u'max': u' $110k',
#    u'mean': u'n/a',
#    u'min': u' $101k'},
#   u'Systems Engineer - Test': {u'count': 1,
#    u'max': u' $119k',
#    u'mean': u'n/a',
#    u'min': u' $109k'},
#   u'Systems Integration Test Engineer': {u'count': 1,
#    u'max': u' $114k',
#    u'mean': u'n/a',
#    u'min': u' $106k'},
#   u'Systems Quality Assurance Engineer': {u'count': 2,
#    u'max': u' $131k',
#    u'mean': u'$118,062',
#    u'min': u' $105k'},
#   u'Systems Quality Assurance Engineer Staff': {u'count': 1,
#    u'max': u' $130k',
#    u'mean': u'n/a',
#    u'min': u' $119k'},
#   u'Systems Quality Assurance Engineering Specialist': {u'count': 1,
#    u'max': u' $101k',
#    u'mean': u'n/a',
#    u'min': u' $92k'},
#   u'Systems Test Engineer': {u'count': 2,
#    u'max': u' $86k',
#    u'mean': u'$82,312',
#    u'min': u' $79k'},
#   u'Technical Assistance Center Engineer Senior': {u'count': 2,
#    u'max': u' $129k',
#    u'mean': u'$108,714',
#    u'min': u' $89k'},
#   u'Technical Assistance Center Engineer Specialist': {u'count': 1,
#    u'max': u' $82k',
#    u'mean': u'n/a',
#    u'min': u' $76k'},
#   u'Technical Expertise Center Engineer': {u'count': 1,
#    u'max': u' $85k',
#    u'mean': u'n/a',
#    u'min': u' $79k'},
#   u'Technical Instructor/Course Developer': {u'count': 1,
#    u'max': u' $137k',
#    u'mean': u'n/a',
#    u'min': u' $128k'},
#   u'Technical Manager': {u'count': 2,
#    u'max': u' $148k',
#    u'mean': u'$128,041',
#    u'min': u' $108k'},
#   u'Technical Project Manager': {u'count': 2,
#    u'max': u' $107k',
#    u'mean': u'$99,686',
#    u'min': u' $93k'},
#   u'Technical Support Engineer': {u'count': 1,
#    u'max': u' $73k',
#    u'mean': u'n/a',
#    u'min': u' $68k'},
#   u'Test Engineer': {u'count': 1,
#    u'max': u' $78k',
#    u'mean': u'n/a',
#    u'min': u' $73k'},
#   u'Test Software Development Engineer': {u'count': 1,
#    u'max': u' $120k',
#    u'mean': u'n/a',
#    u'min': u' $112k'},
#   u'Tis Lte Trials/Foa Engineer': {u'count': 2,
#    u'max': u' $82k',
#    u'mean': u'$78,903',
#    u'min': u' $75k'},
#   u'UMTS Network Design Engineer': {u'count': 1,
#    u'max': u' $104k',
#    u'mean': u'n/a',
#    u'min': u' $96k'},
#   u'UMTS RF/Optimization Engineer': {u'count': 1,
#    u'max': u' $108k',
#    u'mean': u'n/a',
#    u'min': u' $101k'},
#   u'UMTS/Utran Design Engineer': {u'count': 1,
#    u'max': u' $104k',
#    u'mean': u'n/a',
#    u'min': u' $95k'},
#   u'Validation Test Engineer': {u'count': 1,
#    u'max': u' $153k',
#    u'mean': u'n/a',
#    u'min': u' $142k'},
#   u'Venue Solutions RF Engineer': {u'count': 1,
#    u'max': u' $108k',
#    u'mean': u'n/a',
#    u'min': u' $101k'},
#   u'Voice Implementation Engineer': {u'count': 1,
#    u'max': u' $102k',
#    u'mean': u'n/a',
#    u'min': u' $95k'},
#   u'Voice and Data Quality Engineer': {u'count': 4,
#    u'max': u' $110k',
#    u'mean': u'$108,881',
#    u'min': u' $105k'},
#   u'Wireless Bids & Proposals Engineer': {u'count': 1,
#    u'max': u' $74k',
#    u'mean': u'n/a',
#    u'min': u' $67k'},
#   u'Wireless Design Engineer': {u'count': 1,
#    u'max': u' $78k',
#    u'mean': u'n/a',
#    u'min': u' $72k'},
#   u'Wireless Network Data Analyst': {u'count': 1,
#    u'max': u' $100k',
#    u'mean': u'n/a',
#    u'min': u' $92k'},
#   u'Wireless Network Forensic Data Analyst': {u'count': 1,
#    u'max': u' $101k',
#    u'mean': u'n/a',
#    u'min': u' $93k'},
#   u'Wireless Service Provider Data Analytics Engineer': {u'count': 1,
#    u'max': u' $99k',
#    u'mean': u'n/a',
#    u'min': u' $91k'},
#   u'Wireless Systems Engineer': {u'count': 5,
#    u'max': u' $117k',
#    u'mean': u'$106,514',
#    u'min': u' $98k'}}}
